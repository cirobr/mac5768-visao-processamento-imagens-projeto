# %% [markdown]
# MAC 5768 - Visão e Processamento de Imagens
#
# Segundo Semestre - 2020
#
# Equipe:
#
#     Ciro B Rosa - ciro.rosa@alumni.usp.br
#     Josilton Sousa - josilton.sousa@gmail.com
#
# Projeto de elaboração de tarefas do curso de Visão e Processamento de Imagens.
#
#
# Fase 2 - Parte 2 - Entrega em 16/11/2020
#
# Objetivos:
# * Gerar um protótipo médio e histograma correspondente para cada um dos datasets: originalGrayDataset, normalizedGrayDataset, augmentedDataset, normalizedAugmentedDataset.

# %% [markdown]
# Geração de protótipo médio de originalGrayDataset:

# %%
import numpy as np
from skimage import io
import pandas as pd
import matplotlib.pyplot as plt

# adequação do nome de arquivo nos metadados
def fix_jpeg_name(arq):
    arq2 = int(arq[:-4])
    arq2 = str(arq2) + ".jpg"
    return arq2


# ler arquivo de metadados aumentados
p1 = "./originalGrayDataset/"
m1 = "grade.csv"
f1 = p1 + m1
df = pd.read_csv(f1, sep=";")

# pasta de imagens e histogramas médios
p2 = "./averageGrayDataset/"
m2 = "grade.csv"
f2 = p2 + m2

df2=pd.DataFrame(data=None, columns=("tipo_obj", "arquivo"))

# dimensões das fotos
s = [(3096, 4128), (2608, 4640)]

# lista de classes
classes = ["garfo", "faca", "colher", "copo", "caneca", "alicate", "chave", "caneta", "livro", "caderno"]

# varredura de fotos por classes
for i in range(len(classes)):

    # filtrar df para a classe sob análise
    dfx = df[df.objeto == classes[i]]
    
    # criar matriz de soma de fotos
    I0 = np.zeros(s[0])
    I1 = np.zeros(s[1])

    # calcular foto média
    n = 0
    for arq in dfx.arquivo:
        arq = fix_jpeg_name(arq)
        f = p1 + arq
        img = io.imread(f)
        n += 1

        if img.shape not in s:
            img = np.transpose(img)

        if img.shape == s[0]:
            I0 = I0 + img
        else:
            I1 = I1 + img

    if np.all(np.equal(I1, 0)):
        Im = np.divide(I0, n)
    else:
        Im = np.divide(I1, n)

    Im = Im.astype(np.uint8)
    
    # nome do arquivo da foto média
    arqx = classes[i] + "-foto-media" + ".jpg"
    fx = p2 + arqx
    
    # salvar foto média
    io.imsave(fx, Im)
    
    # gravar dados da foto média no dataframe
    l = [classes[i], arqx]
    df2.loc[i] = l
    
    # roda o loop apenas uma vez
    #break

# salvar metadados de fotos médias
print(df2, "\n")
df2.to_csv(f2, index = False, header=True, sep=";")
# Out:
#   tipo_obj                 arquivo
# 0    garfo    garfo-foto-media.jpg
# 1     faca     faca-foto-media.jpg
# 2   colher   colher-foto-media.jpg
# 3     copo     copo-foto-media.jpg
# 4   caneca   caneca-foto-media.jpg
# 5  alicate  alicate-foto-media.jpg
# 6    chave    chave-foto-media.jpg
# 7   caneta   caneta-foto-media.jpg
# 8    livro    livro-foto-media.jpg
# 9  caderno  caderno-foto-media.jpg

# %% [markdown]
# Geração de protótipo médio de normalizedGrayDataset:

# %%
import numpy as np
from skimage import io
import pandas as pd
import matplotlib.pyplot as plt

# adequação do nome de arquivo nos metadados
def fix_jpeg_name(arq):
    arq2 = int(arq[:-4])
    arq2 = str(arq2) + ".jpg"
    return arq2


# ler arquivo de metadados aumentados
p1 = "./normalizedGrayDataset/"
m1 = "grade.csv"
f1 = p1 + m1
df = pd.read_csv(f1, sep=";")

# pasta de imagens e histogramas médios
p2 = "./averageNormalizedGrayDataset/"
m2 = "grade.csv"
f2 = p2 + m2

df2=pd.DataFrame(data=None, columns=("tipo_obj", "arquivo"))

# dimensões das fotos
s = [(3096, 4128), (2608, 4640)]

# lista de classes
classes = ["garfo", "faca", "colher", "copo", "caneca", "alicate", "chave", "caneta", "livro", "caderno"]

# varredura de fotos por classes
for i in range(len(classes)):

    # filtrar df para a classe sob análise
    dfx = df[df.objeto == classes[i]]
    
    # criar matriz de soma de fotos
    I0 = np.zeros(s[0])
    I1 = np.zeros(s[1])

    # calcular foto média
    n = 0
    for arq in dfx.arquivo:
        arq = fix_jpeg_name(arq)
        f = p1 + arq
        img = io.imread(f)
        n += 1

        if img.shape not in s:
            img = np.transpose(img)

        if img.shape == s[0]:
            I0 = I0 + img
        else:
            I1 = I1 + img

    if np.all(np.equal(I1, 0)):
        Im = np.divide(I0, n)
    else:
        Im = np.divide(I1, n)

    Im = Im.astype(np.uint8)
    
    # nome do arquivo da foto média
    arqx = classes[i] + "-foto-media" + ".jpg"
    fx = p2 + arqx
    
    # salvar foto média
    io.imsave(fx, Im)
    
    # gravar dados da foto média no dataframe
    l = [classes[i], arqx]
    df2.loc[i] = l
    
    # roda o loop apenas uma vez
    #break

# salvar metadados de fotos médias
print(df2, "\n")
df2.to_csv(f2, index = False, header=True, sep=";")
# Out:
#   tipo_obj                 arquivo
# 0    garfo    garfo-foto-media.jpg
# 1     faca     faca-foto-media.jpg
# 2   colher   colher-foto-media.jpg
# 3     copo     copo-foto-media.jpg
# 4   caneca   caneca-foto-media.jpg
# 5  alicate  alicate-foto-media.jpg
# 6    chave    chave-foto-media.jpg
# 7   caneta   caneta-foto-media.jpg
# 8    livro    livro-foto-media.jpg
# 9  caderno  caderno-foto-media.jpg

# %% [markdown]
# Geração de protótipo médio de augmentedDataset:

# %%
import numpy as np
from skimage import io
import pandas as pd
import matplotlib.pyplot as plt

# adequação do nome de arquivo nos metadados
def fix_jpeg_name(arq):
    arq2 = int(arq[:-4])
    arq2 = str(arq2) + ".jpg"
    return arq2


# ler arquivo de metadados
p1 = "./augmentedDataset/"
m1 = "grade.csv"
f1 = p1 + m1
df = pd.read_csv(f1, sep=";")

# pasta de imagens e histogramas médios
p2 = "./averageAugmentedDataset/"
m2 = "grade.csv"
f2 = p2 + m2

df2=pd.DataFrame(data=None, columns=("tipo_obj", "arquivo"))

# dimensões das fotos
s = [(3096, 4128), (2608, 4640)]

# lista de classes
classes = ["garfo", "faca", "colher", "copo", "caneca", "alicate", "chave", "caneta", "livro", "caderno"]

# varredura de fotos por classes
for i in range(len(classes)):

    # filtrar df para a classe sob análise
    dfx = df[df.objeto == classes[i]]
    
    # criar matriz de soma de fotos
    I0 = np.zeros(s[0])
    I1 = np.zeros(s[1])

    # calcular foto média
    n = 0
    for arq in dfx.arquivo:
        arq = fix_jpeg_name(arq)
        f = p1 + arq
        img = io.imread(f)
        n += 1

        if img.shape not in s:
            img = np.transpose(img)

        if img.shape == s[0]:
            I0 = I0 + img
        else:
            I1 = I1 + img

    if np.all(np.equal(I1, 0)):
        Im = np.divide(I0, n)
    else:
        Im = np.divide(I1, n)

    Im = Im.astype(np.uint8)
    
    # nome do arquivo da foto média
    arqx = classes[i] + "-foto-media" + ".jpg"
    fx = p2 + arqx
    
    # salvar foto média
    io.imsave(fx, Im)
    
    # gravar dados da foto média no dataframe
    l = [classes[i], arqx]
    df2.loc[i] = l
    
    # roda o loop apenas uma vez
    #break

# salvar metadados de fotos médias
print(df2, "\n")
df2.to_csv(f2, index = False, header=True, sep=";")
# Out:
#   tipo_obj                 arquivo
# 0    garfo    garfo-foto-media.jpg
# 1     faca     faca-foto-media.jpg
# 2   colher   colher-foto-media.jpg
# 3     copo     copo-foto-media.jpg
# 4   caneca   caneca-foto-media.jpg
# 5  alicate  alicate-foto-media.jpg
# 6    chave    chave-foto-media.jpg
# 7   caneta   caneta-foto-media.jpg
# 8    livro    livro-foto-media.jpg
# 9  caderno  caderno-foto-media.jpg

# %% [markdown]
# Geração de protótipo médio de normalizedAugmentedDataset:

# %%
import numpy as np
from skimage import io
import pandas as pd
import matplotlib.pyplot as plt

# adequação do nome de arquivo nos metadados
def fix_jpeg_name(arq):
    arq2 = int(arq[:-4])
    arq2 = str(arq2) + ".jpg"
    return arq2


# ler arquivo de metadados
p1 = "./normalizedAugmentedDataset/"
m1 = "grade.csv"
f1 = p1 + m1
df = pd.read_csv(f1, sep=";")

# pasta de imagens e histogramas médios
p2 = "./averageNormalizedAugmentedDataset/"
m2 = "grade.csv"
f2 = p2 + m2

df2=pd.DataFrame(data=None, columns=("tipo_obj", "arquivo"))

# dimensões das fotos
s = [(3096, 4128), (2608, 4640)]

# lista de classes
classes = ["garfo", "faca", "colher", "copo", "caneca", "alicate", "chave", "caneta", "livro", "caderno"]

# varredura de fotos por classes
for i in range(len(classes)):

    # filtrar df para a classe sob análise
    dfx = df[df.objeto == classes[i]]
    
    # criar matriz de soma de fotos
    I0 = np.zeros(s[0])
    I1 = np.zeros(s[1])

    # calcular foto média
    n = 0
    for arq in dfx.arquivo:
        arq = fix_jpeg_name(arq)
        f = p1 + arq
        img = io.imread(f)
        n += 1

        if img.shape not in s:
            img = np.transpose(img)

        if img.shape == s[0]:
            I0 = I0 + img
        else:
            I1 = I1 + img

    if np.all(np.equal(I1, 0)):
        Im = np.divide(I0, n)
    else:
        Im = np.divide(I1, n)

    Im = Im.astype(np.uint8)
    
    # nome do arquivo da foto média
    arqx = classes[i] + "-foto-media" + ".jpg"
    fx = p2 + arqx
    
    # salvar foto média
    io.imsave(fx, Im)
    
    # gravar dados da foto média no dataframe
    l = [classes[i], arqx]
    df2.loc[i] = l
    
    # roda o loop apenas uma vez
    #break

# salvar metadados de fotos médias
print(df2, "\n")
df2.to_csv(f2, index = False, header=True, sep=";")
# Out:
#   tipo_obj                 arquivo
# 0    garfo    garfo-foto-media.jpg
# 1     faca     faca-foto-media.jpg
# 2   colher   colher-foto-media.jpg
# 3     copo     copo-foto-media.jpg
# 4   caneca   caneca-foto-media.jpg
# 5  alicate  alicate-foto-media.jpg
# 6    chave    chave-foto-media.jpg
# 7   caneta   caneta-foto-media.jpg
# 8    livro    livro-foto-media.jpg
# 9  caderno  caderno-foto-media.jpg
