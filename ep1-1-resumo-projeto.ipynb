# %% [markdown]
# MAC 5768 - Visão e Processamento de Imagens
#
# Segundo Semestre - 2020
#
#
# Resumo de Projeto
#
#
# Equipe:
# * Ciro B Rosa - ciro.rosa@alumni.usp.br
# * Josilton Sousa - josilton.sousa@gmail.com
#
#
# Introdução
#
# Projeto de elaboração de tarefas do curso de Visão e Processamento de Imagens.
#
#
# Fase 1, Parte 1 - Entrega em 5/10/2020
#
# Esta fase tem por objetivo a criação de um banco de dados de fotos com variabilidade e condições suficientes para poderem ser usadas ao longo do curso. Os requisitos foram os seguintes:
#
# - 10 (dez objetos distintos): Neste projeto: garfo, faca, colher, copo, caneca, alicate, chave, caneta, livro, caderno.
# - Três tipos diferentes para cada um dos 10 objetos
# - Fotografias tiradas sobre três tipos de fundo distintos: branco, xadrez, mickey.
# - Quatro condições de iluminação distintas: indoor dia, indoor noite, outdoor dia, outdoor noite.
# - Três fotos para cada condição única, resultado das diferentes combinações acima.
# - Total de 1080 fotos (3 GB).
#
#
# Cada membro da equipe ficou encarregado de obter a metade das fotos sendo que a divisão de tarefas foi como segue:
#
# - Ciro: alicate, chave, caneta, livro, caderno.
# - Josilton: garfo, faca, colher, copo, caneca.
#
#
# Como cada membro utilizou sua própria câmera fotográfica, é importante registrar as informações técnicas de cada uma delas:
#
# - Câmera Ciro: Celular Asus Zenfone Selfie 4 Pro, resolução 12 MPixels, formato 16:9
# - Câmera Josilton:Celular Sansung Galaxy A10, resolução 13 MPixels, formato 16:9
#
#
# Entregáveis da Fase 1:
# * Repositório do projeto (Github): https://github.com/cirobr/mac5768-projeto
#
# * Repositório de fotos (Google Drive): https://drive.google.com/open?id=13HaOI0t01PfVSvHIRkNJ9nU0mDoPYpdW&authuser=ciro.rosa%40alumni.usp.br&usp=drive_fs
#
# * Arquivo de metadados: "./dados/grade-fotos.csv"
#
# * Resumo do projeto (este arquivo): Jupyter Notebook "resumo-projeto.ipynb"
#
# * Display de classes/objetos: Jupyter Notebook "mnist-like.ipynb" contendo código e display com fotos representativas de cada objeto/classe em estudo.
#
#
# Geração de arquivo de metadados:
#
# O código em R a seguir foi utilizado para gerar uma tabela com as características de todas as combinações de fotos necessárias (total de 1080 fotos). Cada linha do arquivo corresponde a uma combinação única dos requisitos de fotos para o projeto, as quais se correlacionam com as fotos obtidas através dos respectivos nomes de arquivos. Por exemplo, a primeira foto do arquivo de metadados está armazenada como "1.jpg", e a última como "1080.jpg".

# %%
library(tidyverse)
library(readxl)

classes <- c("garfo", "faca", "colher", "copo", "caneca", "alicate", "chave", "caneta", "livro", "caderno")
tipo <- c("a", "b", "c")
fundo <- c("branco", "mickey", "xadrez")
local <- c("indoor", "outdoor")
horario <- c("dia", "noite")
sequencia <- c("1", "2", "3")

local_hora <- expand.grid(local, horario)
local_hora <- paste(local_hora$Var1, local_hora$Var2)

grade <- expand.grid(sequencia = sequencia,
                     objeto = classes,
                     tipo_obj = tipo,
                     fundo = fundo,
                     iluminação = local_hora)
grade <- grade %>% mutate(responsavel = ifelse(objeto %in% classes[1:5],
                                               "Josilton",
                                               "Ciro"),
                          arquivo = paste(row_number(), ".jpg"))
head(grade)
write_excel_csv2(grade, "./originalDataset/grade.csv")
# Out:
#   sequencia objeto tipo_obj fundo  iluminação responsavel arquivo
# 1 1         garfo  a        branco indoor dia Josilton    1 .jpg
# 2 2         garfo  a        branco indoor dia Josilton    2 .jpg
# 3 3         garfo  a        branco indoor dia Josilton    3 .jpg
# 4 1         faca   a        branco indoor dia Josilton    4 .jpg
# 5 2         faca   a        branco indoor dia Josilton    5 .jpg
# 6 3         faca   a        branco indoor dia Josilton    6 .jpg
