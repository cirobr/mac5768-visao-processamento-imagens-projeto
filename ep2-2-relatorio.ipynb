# %% [markdown]
# MAC 5768 - Visão e Processamento de Imagens
#
# Segundo Semestre - 2020
#
# Equipe:
#
#     Ciro B Rosa - ciro.rosa@alumni.usp.br
#     Josilton Sousa - josilton.sousa@gmail.com
#
# Projeto de elaboração de tarefas do curso de Visão e Processamento de Imagens.
#
#
# Fase 2 - Parte 2 - Entrega em 16/11/2020
#
# Objetivos:
# * Gerar um "normalizedDataset" a partir do "augmentedDataset".
# * Apresentar imagem de "protótipo médio" e respectivo histograma para o augmentedDataset.
# * Idem acima, para o "normalizedDataset".
# * Apresentar análise comparativa entre os protótipos médios do "augmentedDataset" e do "normalizedDataset".

# %% [markdown]
# O código a seguir gera a partir do "augmentedDataset" uma imagem de "protótipo médio" para cada classe/tipo de objeto. Esta imagem de protótipo médio corresponde à soma matricial de todas as imagens de um mesmo objeto, posteriormente dividida pela quantidade de imagens somadas.
#
# As imagens de protótipo médio são gravadas no arquivo "averageAugmentedDataset" junto com os respectivos metadados.

# %%
import numpy as np
from skimage import io
import pandas as pd
import matplotlib.pyplot as plt

# adequação do nome de arquivo nos metadados
def fix_jpeg_name(arq):
    arq2 = int(arq[:-4])
    arq2 = str(arq2) + ".jpg"
    return arq2


# ler arquivo de dados
p1 = "./augmentedDataset/"
m1 = "grade-augmented.csv"
f1 = p1 + m1
df = pd.read_csv(f1, sep=";")

# pasta de imagens e histogramas médios
p2 = "./averageAugmentedDataset/"
m2 = "grade-avg-augmented.csv"
f2 = p2 + m2

df2=pd.DataFrame(data=None, columns=("tipo_obj", "arquivo"))
#df2_length = len(df2)

# dimensões das fotos
s = [(3096, 4128), (2608, 4640)]

# lista de classes
classes = ["garfo", "faca", "colher", "copo", "caneca", "alicate", "chave", "caneta", "livro", "caderno"]

# varredura de fotos por classes
for i in range(len(classes)):

    # filtrar df para a classe sob análise
    dfx = df[df.objeto == classes[i]]
    print(dfx.head(5), "\n")
    
    # criar matriz de soma de fotos
    I0 = np.zeros(s[0])
    I1 = np.zeros(s[1])

    # calcular foto média
    n = 0
    for arq in dfx.arquivo:
        arq = fix_jpeg_name(arq)
        f = p1 + arq
        img = io.imread(f)
        n += 1

        if img.shape not in s:
            img = np.transpose(img)

        if img.shape == s[0]:
            I0 = I0 + img
        else:
            I1 = I1 + img

    if np.all(np.equal(I1, 0)):
        Im = np.divide(I0, n)
    else:
        Im = np.divide(I1, n)

    Im = Im.astype(np.uint8)
    
    # nome do arquivo da foto média
    arqx = classes[i] + "-foto-media" + ".jpg"
    fx = p2 + arqx
    
    # salvar foto média
    io.imsave(fx, Im)
    
    # gravar dados da foto média no dataframe
    l = [classes[i], arqx]
    df2.loc[i] = l
    
    # roda o loop apenas uma vez
    #break

# salvar metadados de fotos médias
print(df2, "\n")
df2.to_csv(f2, index = False, header=True, sep=";")
# Out:
#     sequencia objeto tipo_obj   fundo  iluminacao transformacao responsavel  \
# 0           1  garfo        a  branco  indoor dia         cinza    Josilton
# 1           2  garfo        a  branco  indoor dia         cinza    Josilton
# 2           3  garfo        a  branco  indoor dia         cinza    Josilton
# 30          1  garfo        b  branco  indoor dia         cinza    Josilton
# 31          2  garfo        b  branco  indoor dia         cinza    Josilton
#
#      arquivo
# 0   1081.jpg
# 1   1082.jpg
# 2   1083.jpg
# 30  1111.jpg
# 31  1112.jpg
#
#     sequencia objeto tipo_obj   fundo  iluminacao transformacao responsavel  \
# 3           1   faca        a  branco  indoor dia         cinza    Josilton
# 4           2   faca        a  branco  indoor dia         cinza    Josilton
# 5           3   faca        a  branco  indoor dia         cinza    Josilton
# 33          1   faca        b  branco  indoor dia         cinza    Josilton
# 34          2   faca        b  branco  indoor dia         cinza    Josilton
#
#      arquivo
# 3   1084.jpg
# 4   1085.jpg
# 5   1086.jpg
# 33  1114.jpg
# 34  1115.jpg
#
#     sequencia  objeto tipo_obj   fundo  iluminacao transformacao responsavel  \
# 6           1  colher        a  branco  indoor dia         cinza    Josilton
# 7           2  colher        a  branco  indoor dia         cinza    Josilton
# 8           3  colher        a  branco  indoor dia         cinza    Josilton
# 36          1  colher        b  branco  indoor dia         cinza    Josilton
# 37          2  colher        b  branco  indoor dia         cinza    Josilton
#
#      arquivo
# 6   1087.jpg
# 7   1088.jpg
# 8   1089.jpg
# 36  1117.jpg
# 37  1118.jpg
#
#     sequencia objeto tipo_obj   fundo  iluminacao transformacao responsavel  \
# 9           1   copo        a  branco  indoor dia         cinza    Josilton
# 10          2   copo        a  branco  indoor dia         cinza    Josilton
# 11          3   copo        a  branco  indoor dia         cinza    Josilton
# 39          1   copo        b  branco  indoor dia         cinza    Josilton
# 40          2   copo        b  branco  indoor dia         cinza    Josilton
#
#      arquivo
# 9   1090.jpg
# 10  1091.jpg
# 11  1092.jpg
# 39  1120.jpg
# 40  1121.jpg
#
#     sequencia  objeto tipo_obj   fundo  iluminacao transformacao responsavel  \
# 12          1  caneca        a  branco  indoor dia         cinza    Josilton
# 13          2  caneca        a  branco  indoor dia         cinza    Josilton
# 14          3  caneca        a  branco  indoor dia         cinza    Josilton
# 42          1  caneca        b  branco  indoor dia         cinza    Josilton
# 43          2  caneca        b  branco  indoor dia         cinza    Josilton
#
#      arquivo
# 12  1093.jpg
# 13  1094.jpg
# 14  1095.jpg
# 42  1123.jpg
# 43  1124.jpg
#
#     sequencia   objeto tipo_obj   fundo  iluminacao transformacao responsavel  \
# 15          1  alicate        a  branco  indoor dia         cinza        Ciro
# 16          2  alicate        a  branco  indoor dia         cinza        Ciro
# 17          3  alicate        a  branco  indoor dia         cinza        Ciro
# 45          1  alicate        b  branco  indoor dia         cinza        Ciro
# 46          2  alicate        b  branco  indoor dia         cinza        Ciro
#
#      arquivo
# 15  1096.jpg
# 16  1097.jpg
# 17  1098.jpg
# 45  1126.jpg
# 46  1127.jpg
#
#     sequencia objeto tipo_obj   fundo  iluminacao transformacao responsavel  \
# 18          1  chave        a  branco  indoor dia         cinza        Ciro
# 19          2  chave        a  branco  indoor dia         cinza        Ciro
# 20          3  chave        a  branco  indoor dia         cinza        Ciro
# 48          1  chave        b  branco  indoor dia         cinza        Ciro
# 49          2  chave        b  branco  indoor dia         cinza        Ciro
#
#      arquivo
# 18  1099.jpg
# 19  1100.jpg
# 20  1101.jpg
# 48  1129.jpg
# 49  1130.jpg
#
#     sequencia  objeto tipo_obj   fundo  iluminacao transformacao responsavel  \
# 21          1  caneta        a  branco  indoor dia         cinza        Ciro
# 22          2  caneta        a  branco  indoor dia         cinza        Ciro
# 23          3  caneta        a  branco  indoor dia         cinza        Ciro
# 51          1  caneta        b  branco  indoor dia         cinza        Ciro
# 52          2  caneta        b  branco  indoor dia         cinza        Ciro
#
#      arquivo
# 21  1102.jpg
# 22  1103.jpg
# 23  1104.jpg
# 51  1132.jpg
# 52  1133.jpg
#
#     sequencia objeto tipo_obj   fundo  iluminacao transformacao responsavel  \
# 24          1  livro        a  branco  indoor dia         cinza        Ciro
# 25          2  livro        a  branco  indoor dia         cinza        Ciro
# 26          3  livro        a  branco  indoor dia         cinza        Ciro
# 54          1  livro        b  branco  indoor dia         cinza        Ciro
# 55          2  livro        b  branco  indoor dia         cinza        Ciro
#
#      arquivo
# 24  1105.jpg
# 25  1106.jpg
# 26  1107.jpg
# 54  1135.jpg
# 55  1136.jpg
#
#     sequencia   objeto tipo_obj   fundo  iluminacao transformacao responsavel  \
# 27          1  caderno        a  branco  indoor dia         cinza        Ciro
# 28          2  caderno        a  branco  indoor dia         cinza        Ciro
# 29          3  caderno        a  branco  indoor dia         cinza        Ciro
# 57          1  caderno        b  branco  indoor dia         cinza        Ciro
# 58          2  caderno        b  branco  indoor dia         cinza        Ciro
#
#      arquivo
# 27  1108.jpg
# 28  1109.jpg
# 29  1110.jpg
# 57  1138.jpg
# 58  1139.jpg
#
#   tipo_obj                 arquivo
# 0    garfo    garfo-foto-media.jpg
# 1     faca     faca-foto-media.jpg
# 2   colher   colher-foto-media.jpg
# 3     copo     copo-foto-media.jpg
# 4   caneca   caneca-foto-media.jpg
# 5  alicate  alicate-foto-media.jpg
# 6    chave    chave-foto-media.jpg
# 7   caneta   caneta-foto-media.jpg
# 8    livro    livro-foto-media.jpg
# 9  caderno  caderno-foto-media.jpg

# %% [markdown]
# De forma similar, o código a seguir gera a partir do "normalizedDataset" uma imagem de "protótipo médio" para cada classe/tipo de objeto.
#
# As imagens de protótipo médio são gravadas no arquivo "averageNormalizedDataset" junto com os respectivos metadados.

# %%
import numpy as np
from skimage import io
import pandas as pd
import matplotlib.pyplot as plt

# adequação do nome de arquivo nos metadados
def fix_jpeg_name(arq):
    arq2 = int(arq[:-4])
    arq2 = str(arq2) + ".jpg"
    return arq2


# ler arquivo de dados
p1 = "./normalizedDataset/"
m1 = "grade-normalized.csv"
f1 = p1 + m1
df = pd.read_csv(f1, sep=";")

# pasta de imagens e histogramas médios
p2 = "./averageNormalizedDataset/"
m2 = "grade-avg-normalized.csv"
f2 = p2 + m2

df2=pd.DataFrame(data=None, columns=("tipo_obj", "arquivo"))
#df2_length = len(df2)

# dimensões das fotos
s = [(3096, 4128), (2608, 4640)]

# lista de classes
classes = ["garfo", "faca", "colher", "copo", "caneca", "alicate", "chave", "caneta", "livro", "caderno"]

# varredura de fotos por classes
for i in range(len(classes)):

    # filtrar df para a classe sob análise
    dfx = df[df.objeto == classes[i]]
    print(dfx.head(5), "\n")
    
    # criar matriz de soma de fotos
    I0 = np.zeros(s[0])
    I1 = np.zeros(s[1])

    # calcular foto média
    n = 0
    for arq in dfx.arquivo:
        arq = fix_jpeg_name(arq)
        f = p1 + arq
        img = io.imread(f)
        n += 1

        if img.shape not in s:
            img = np.transpose(img)

        if img.shape == s[0]:
            I0 = I0 + img
        else:
            I1 = I1 + img

    if np.all(np.equal(I1, 0)):
        Im = np.divide(I0, n)
    else:
        Im = np.divide(I1, n)

    Im = Im.astype(np.uint8)
    
    # nome do arquivo da foto média
    arqx = classes[i] + "-foto-media" + ".jpg"
    fx = p2 + arqx
    
    # salvar foto média
    io.imsave(fx, Im)
    
    # gravar dados da foto média no dataframe
    l = [classes[i], arqx]
    df2.loc[i] = l
    
    # roda o loop apenas uma vez
    #break

# salvar metadados de fotos médias
print(df2, "\n")
df2.to_csv(f2, index = False, header=True, sep=";")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-e1b1503ee46c> in <module>
#      15 m1 = "grade-normalized.csv"
#      16 f1 = p1 + m1
# ---> 17 df = pd.read_csv(f1, sep=";")
#      18
#      19 # pasta de imagens e histogramas médios
#
# ~/anaconda3/envs/mac/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# ~/anaconda3/envs/mac/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# ~/anaconda3/envs/mac/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# ~/anaconda3/envs/mac/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# ~/anaconda3/envs/mac/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: './normalizedDataset/grade-normalized.csv'
